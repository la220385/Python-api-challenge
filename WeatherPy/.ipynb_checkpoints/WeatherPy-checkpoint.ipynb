# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name

    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 594

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
import requests
import time
import random
from citipy import citipy

# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather"
weather_api_key = "be30130d8cd8c0d1146e214d31e7ff18"

# Create empty lists for latitude, longitude, and city information
latitude = []
longitude = []
cities = []

# Generate 1500 random geographic coordinates (latitude and longitude)
for _ in range(1500):
    lat = random.uniform(-90.0, 90.0)
    lon = random.uniform(-180.0, 180.0)
    latitude.append(lat)
    longitude.append(lon)

    # Use citipy to find the nearest city for each latitude/longitude combination
    city = citipy.nearest_city(lat, lon).city_name

    # Add city if it's not already in the list (to avoid duplicates)
    if city not in cities:
        cities.append(city)

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in your list to fetch weather data
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{url}?q={city}&appid={weather_api_key}&units=metric"

    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({
            "City": city,
            "Lat": city_lat,
            "Lng": city_lng,
            "Max Temp": city_max_temp,
            "Humidity": city_humidity,
            "Cloudiness": city_clouds,
            "Wind Speed": city_wind,
            "Country": city_country,
            "Date": city_date
        })

    # If an error is experienced, skip the city
    except Exception as e:
        print(f"City not found: {city}. Skipping...")

    # Pause to avoid rate limiting
    time.sleep(1)

# Indicate that Data Loading is complete
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | venadillo
# Processing Record 2 of Set 1 | hamilton
# Processing Record 3 of Set 1 | kalemie
# Processing Record 4 of Set 1 | iqaluit
# Processing Record 5 of Set 1 | hermanus
# Processing Record 6 of Set 1 | tsiombe
# Processing Record 7 of Set 1 | djambala
# Processing Record 8 of Set 1 | grytviken
# Processing Record 9 of Set 1 | port-aux-francais
# Processing Record 10 of Set 1 | ushuaia
# Processing Record 11 of Set 1 | mili
# Processing Record 12 of Set 1 | antalaha
# Processing Record 13 of Set 1 | vilyuchinsk
# Processing Record 14 of Set 1 | bethel
# Processing Record 15 of Set 1 | port mathurin
# Processing Record 16 of Set 1 | hayma'
# City not found: hayma'. Skipping...
# Processing Record 17 of Set 1 | severnoye
# Processing Record 18 of Set 1 | adamstown
# Processing Record 19 of Set 1 | nova sintra
# Processing Record 20 of Set 1 | rongelap
# Processing Record 21 of Set 1 | guerrero negro
# Processing Record 22 of Set 1 | lazaro cardenas
# Processing Record 23 of Set 1 | mumbwa
# Processing Record 24 of Set 1 | north bondi
# Processing Record 25 of Set 1 | touros
# Processing Record 26 of Set 1 | zeya
# Processing Record 27 of Set 1 | st. john's
# Processing Record 28 of Set 1 | albany
# Processing Record 29 of Set 1 | kimbe
# Processing Record 30 of Set 1 | ta`u
# Processing Record 31 of Set 1 | isafjordur
# Processing Record 32 of Set 1 | walvis bay
# Processing Record 33 of Set 1 | chibougamau
# Processing Record 34 of Set 1 | tazovsky
# Processing Record 35 of Set 1 | blackmans bay
# Processing Record 36 of Set 1 | plettenberg bay
# Processing Record 37 of Set 1 | waitangi
# Processing Record 38 of Set 1 | kone
# Processing Record 39 of Set 1 | betio village
# Processing Record 40 of Set 1 | port saint john's
# Processing Record 41 of Set 1 | margaret river
# Processing Record 42 of Set 1 | tranovaho
# City not found: tranovaho. Skipping...
# Processing Record 43 of Set 1 | rukban
# City not found: rukban. Skipping...
# Processing Record 44 of Set 1 | colonia
# Processing Record 45 of Set 1 | remire-montjoly
# Processing Record 46 of Set 1 | ilulissat
# Processing Record 47 of Set 1 | bilibino
# Processing Record 48 of Set 1 | avarua
# Processing Record 49 of Set 1 | brookings
# Processing Record 50 of Set 1 | nagqu
# Processing Record 0 of Set 2 | lucapa
# Processing Record 1 of Set 2 | tiksi
# Processing Record 2 of Set 2 | ahau
# City not found: ahau. Skipping...
# Processing Record 3 of Set 2 | saldanha
# Processing Record 4 of Set 2 | preobrazheniye
# Processing Record 5 of Set 2 | puerto natales
# Processing Record 6 of Set 2 | mana
# Processing Record 7 of Set 2 | buckeye
# Processing Record 8 of Set 2 | tolanaro
# Processing Record 9 of Set 2 | georgetown
# Processing Record 10 of Set 2 | alice springs
# Processing Record 11 of Set 2 | am djarass
# City not found: am djarass. Skipping...
# Processing Record 12 of Set 2 | fale old settlement
# Processing Record 13 of Set 2 | 'ohonua
# City not found: 'ohonua. Skipping...
# Processing Record 14 of Set 2 | ancud
# Processing Record 15 of Set 2 | college
# Processing Record 16 of Set 2 | arraial do cabo
# Processing Record 17 of Set 2 | yellowknife
# Processing Record 18 of Set 2 | akureyri
# Processing Record 19 of Set 2 | teius
# Processing Record 20 of Set 2 | iskateley
# Processing Record 21 of Set 2 | ouani
# Processing Record 22 of Set 2 | alto barinas
# Processing Record 23 of Set 2 | sinabang
# Processing Record 24 of Set 2 | quang ngai
# Processing Record 25 of Set 2 | karkira
# Processing Record 26 of Set 2 | labrador city
# Processing Record 27 of Set 2 | edinburgh of the seven seas
# Processing Record 28 of Set 2 | luderitz
# Processing Record 29 of Set 2 | papatowai
# Processing Record 30 of Set 2 | grand falls-windsor
# Processing Record 31 of Set 2 | cill airne
# Processing Record 32 of Set 2 | puerto deseado
# Processing Record 33 of Set 2 | taiohae
# City not found: taiohae. Skipping...
# Processing Record 34 of Set 2 | hawaiian paradise park
# Processing Record 35 of Set 2 | margate
# Processing Record 36 of Set 2 | tongouson
# Processing Record 37 of Set 2 | hasaki
# Processing Record 38 of Set 2 | revda
# Processing Record 39 of Set 2 | mission
# Processing Record 40 of Set 2 | palikir - national government center
# Processing Record 41 of Set 2 | yaren
# Processing Record 42 of Set 2 | siwa oasis
# Processing Record 43 of Set 2 | petropavlovsk-kamchatsky
# Processing Record 44 of Set 2 | nacozari de garcia
# Processing Record 45 of Set 2 | lihue
# Processing Record 46 of Set 2 | pisco
# Processing Record 47 of Set 2 | happy valley-goose bay
# Processing Record 48 of Set 2 | udachny
# Processing Record 49 of Set 2 | ape
# Processing Record 0 of Set 3 | timimoun
# Processing Record 1 of Set 3 | carbonear
# Processing Record 2 of Set 3 | ribeira grande
# Processing Record 3 of Set 3 | sola
# Processing Record 4 of Set 3 | talnakh
# Processing Record 5 of Set 3 | trinidad
# Processing Record 6 of Set 3 | la mira
# Processing Record 7 of Set 3 | murzuq
# Processing Record 8 of Set 3 | shendi
# Processing Record 9 of Set 3 | sungai penuh
# Processing Record 10 of Set 3 | puerto san carlos
# City not found: puerto san carlos. Skipping...
# Processing Record 11 of Set 3 | anna regina
# Processing Record 12 of Set 3 | tostado
# Processing Record 13 of Set 3 | iwanai
# Processing Record 14 of Set 3 | dryden
# Processing Record 15 of Set 3 | wailua homesteads
# Processing Record 16 of Set 3 | suntar
# Processing Record 17 of Set 3 | kristiansund
# Processing Record 18 of Set 3 | dudinka
# Processing Record 19 of Set 3 | utrik
# Processing Record 20 of Set 3 | afaahiti
# Processing Record 21 of Set 3 | quibdo
# Processing Record 22 of Set 3 | xinyuan
# Processing Record 23 of Set 3 | jamestown
# Processing Record 24 of Set 3 | remontnoye
# Processing Record 25 of Set 3 | yamba
# City not found: yamba. Skipping...
# Processing Record 26 of Set 3 | chonchi
# Processing Record 27 of Set 3 | mount pearl
# Processing Record 28 of Set 3 | whitehorse
# Processing Record 29 of Set 3 | kingston
# Processing Record 30 of Set 3 | iskitim
# Processing Record 31 of Set 3 | bela
# Processing Record 32 of Set 3 | emerald
# Processing Record 33 of Set 3 | oasis
# Processing Record 34 of Set 3 | kaiama
# Processing Record 35 of Set 3 | jiayuguan
# Processing Record 36 of Set 3 | port lincoln
# Processing Record 37 of Set 3 | enewetak
# Processing Record 38 of Set 3 | myitkyina
# Processing Record 39 of Set 3 | salamanca
# Processing Record 40 of Set 3 | bamboo flat
# Processing Record 41 of Set 3 | wanning
# Processing Record 42 of Set 3 | itamaraca
# Processing Record 43 of Set 3 | newman
# Processing Record 44 of Set 3 | magadan
# Processing Record 45 of Set 3 | sao vicente
# Processing Record 46 of Set 3 | svetlyy
# Processing Record 47 of Set 3 | qaqortoq
# Processing Record 48 of Set 3 | san patricio
# Processing Record 49 of Set 3 | hithadhoo
# Processing Record 0 of Set 4 | manokwari
# Processing Record 1 of Set 4 | howrah
# Processing Record 2 of Set 4 | aykhal
# Processing Record 3 of Set 4 | khorol
# Processing Record 4 of Set 4 | pavilosta
# Processing Record 5 of Set 4 | bredasdorp
# Processing Record 6 of Set 4 | ninh binh
# Processing Record 7 of Set 4 | gubkinskiy
# Processing Record 8 of Set 4 | raseiniai
# Processing Record 9 of Set 4 | ciranjang-hilir
# Processing Record 10 of Set 4 | hadibu
# Processing Record 11 of Set 4 | hotan
# Processing Record 12 of Set 4 | khandyga
# Processing Record 13 of Set 4 | kruisfontein
# Processing Record 14 of Set 4 | palu
# Processing Record 15 of Set 4 | pitimbu
# Processing Record 16 of Set 4 | port alfred
# Processing Record 17 of Set 4 | vila franca do campo
# Processing Record 18 of Set 4 | san juan de miraflores
# Processing Record 19 of Set 4 | west island
# Processing Record 20 of Set 4 | olinda
# Processing Record 21 of Set 4 | tonkino
# Processing Record 22 of Set 4 | lompoc
# Processing Record 23 of Set 4 | kharp
# Processing Record 24 of Set 4 | punta arenas
# Processing Record 25 of Set 4 | northam
# Processing Record 26 of Set 4 | weno
# Processing Record 27 of Set 4 | san antonio de pale
# Processing Record 28 of Set 4 | estes park
# Processing Record 29 of Set 4 | el granada
# Processing Record 30 of Set 4 | la passe
# Processing Record 31 of Set 4 | okahao
# Processing Record 32 of Set 4 | polyarnyy
# Processing Record 33 of Set 4 | murashi
# Processing Record 34 of Set 4 | sao felix do xingu
# Processing Record 35 of Set 4 | mar del plata
# Processing Record 36 of Set 4 | tsengel
# Processing Record 37 of Set 4 | sawakin
# Processing Record 38 of Set 4 | beidao
# Processing Record 39 of Set 4 | anadyr
# Processing Record 40 of Set 4 | kangding
# Processing Record 41 of Set 4 | ed damer
# Processing Record 42 of Set 4 | aykol
# Processing Record 43 of Set 4 | de aar
# Processing Record 44 of Set 4 | kununurra
# Processing Record 45 of Set 4 | naze
# Processing Record 46 of Set 4 | skowhegan
# Processing Record 47 of Set 4 | tamandare
# Processing Record 48 of Set 4 | selfoss
# Processing Record 49 of Set 4 | wakkanai
# Processing Record 0 of Set 5 | kapa'a
# Processing Record 1 of Set 5 | kodiak
# Processing Record 2 of Set 5 | fort bragg
# Processing Record 3 of Set 5 | port augusta
# Processing Record 4 of Set 5 | kupang
# Processing Record 5 of Set 5 | holualoa
# Processing Record 6 of Set 5 | vorgashor
# Processing Record 7 of Set 5 | egilsstadir
# Processing Record 8 of Set 5 | ribeira brava
# Processing Record 9 of Set 5 | karabash
# Processing Record 10 of Set 5 | olonkinbyen
# Processing Record 11 of Set 5 | madang
# Processing Record 12 of Set 5 | nova vicosa
# Processing Record 13 of Set 5 | coahuayana de hidalgo
# Processing Record 14 of Set 5 | garoua boulai
# Processing Record 15 of Set 5 | kapit
# Processing Record 16 of Set 5 | flying fish cove
# Processing Record 17 of Set 5 | san luis de la loma
# Processing Record 18 of Set 5 | hammerfest
# Processing Record 19 of Set 5 | beipiao
# Processing Record 20 of Set 5 | kataragama
# City not found: kataragama. Skipping...
# Processing Record 21 of Set 5 | nako
# Processing Record 22 of Set 5 | tura
# Processing Record 23 of Set 5 | lorengau
# Processing Record 24 of Set 5 | daru
# Processing Record 25 of Set 5 | turpan
# Processing Record 26 of Set 5 | minas de marcona
# Processing Record 27 of Set 5 | vojens
# Processing Record 28 of Set 5 | kulia village
# City not found: kulia village. Skipping...
# Processing Record 29 of Set 5 | badger
# Processing Record 30 of Set 5 | calama
# Processing Record 31 of Set 5 | khirkiyan
# Processing Record 32 of Set 5 | gadzhiyevo
# Processing Record 33 of Set 5 | ripley
# Processing Record 34 of Set 5 | vadso
# Processing Record 35 of Set 5 | zhigalovo
# Processing Record 36 of Set 5 | jianshui
# Processing Record 37 of Set 5 | tvoroyri
# Processing Record 38 of Set 5 | tara
# Processing Record 39 of Set 5 | kurumkan
# Processing Record 40 of Set 5 | barra de santo antonio
# Processing Record 41 of Set 5 | port elizabeth
# Processing Record 42 of Set 5 | el burgo de osma
# Processing Record 43 of Set 5 | beitbridge
# Processing Record 44 of Set 5 | espargos
# City not found: espargos. Skipping...
# Processing Record 45 of Set 5 | valparaiso
# Processing Record 46 of Set 5 | ibipeba
# Processing Record 47 of Set 5 | bolhrad
# Processing Record 48 of Set 5 | mangrol
# Processing Record 49 of Set 5 | deqen
# Processing Record 0 of Set 6 | stanley
# Processing Record 1 of Set 6 | ndele
# Processing Record 2 of Set 6 | pyt-yakh
# Processing Record 3 of Set 6 | okha
# Processing Record 4 of Set 6 | atafu village
# Processing Record 5 of Set 6 | arno
# Processing Record 6 of Set 6 | khromtau
# Processing Record 7 of Set 6 | al jawf
# Processing Record 8 of Set 6 | boa esperanca
# Processing Record 9 of Set 6 | portland
# Processing Record 10 of Set 6 | saguenay
# Processing Record 11 of Set 6 | blenheim
# Processing Record 12 of Set 6 | tateyama
# Processing Record 13 of Set 6 | porto velho
# Processing Record 14 of Set 6 | nar'yan-mar
# Processing Record 15 of Set 6 | westport
# Processing Record 16 of Set 6 | inhambane
# Processing Record 17 of Set 6 | severo-yeniseyskiy
# Processing Record 18 of Set 6 | invercargill
# Processing Record 19 of Set 6 | yinchuan
# Processing Record 20 of Set 6 | machachi
# Processing Record 21 of Set 6 | tshabong
# Processing Record 22 of Set 6 | las tablas
# Processing Record 23 of Set 6 | fortuna
# Processing Record 24 of Set 6 | tual
# Processing Record 25 of Set 6 | kayangel
# Processing Record 26 of Set 6 | mount gambier
# Processing Record 27 of Set 6 | longyearbyen
# Processing Record 28 of Set 6 | beardstown
# Processing Record 29 of Set 6 | benguela
# Processing Record 30 of Set 6 | cabo san lucas
# Processing Record 31 of Set 6 | tralee
# Processing Record 32 of Set 6 | nuuk
# Processing Record 33 of Set 6 | salmon arm
# Processing Record 34 of Set 6 | oranjemund
# Processing Record 35 of Set 6 | vila velha
# Processing Record 36 of Set 6 | kapuskasing
# Processing Record 37 of Set 6 | cockburn town
# Processing Record 38 of Set 6 | rosoman
# Processing Record 39 of Set 6 | puerto ayora
# Processing Record 40 of Set 6 | pivijay
# Processing Record 41 of Set 6 | kargasok
# Processing Record 42 of Set 6 | saipan
# Processing Record 43 of Set 6 | susuman
# Processing Record 44 of Set 6 | kirensk
# Processing Record 45 of Set 6 | springbok
# Processing Record 46 of Set 6 | ulsteinvik
# Processing Record 47 of Set 6 | constantia
# Processing Record 48 of Set 6 | quelimane
# Processing Record 49 of Set 6 | dien bien phu
# Processing Record 0 of Set 7 | faya-largeau
# Processing Record 1 of Set 7 | san andres
# Processing Record 2 of Set 7 | crane
# Processing Record 3 of Set 7 | geraldton
# Processing Record 4 of Set 7 | douz
# Processing Record 5 of Set 7 | victorica
# Processing Record 6 of Set 7 | kalibo (poblacion)
# Processing Record 7 of Set 7 | kiruna
# Processing Record 8 of Set 7 | meadow lakes
# Processing Record 9 of Set 7 | lagoa santa
# Processing Record 10 of Set 7 | wewak
# Processing Record 11 of Set 7 | pyhajarvi
# Processing Record 12 of Set 7 | ovalle
# Processing Record 13 of Set 7 | turkmenbasy
# Processing Record 14 of Set 7 | alaghsas
# Processing Record 15 of Set 7 | sishilichengzi
# City not found: sishilichengzi. Skipping...
# Processing Record 16 of Set 7 | codrington
# Processing Record 17 of Set 7 | santa marta
# Processing Record 18 of Set 7 | miri
# Processing Record 19 of Set 7 | amursk
# Processing Record 20 of Set 7 | cromer
# Processing Record 21 of Set 7 | junin de los andes
# Processing Record 22 of Set 7 | ebon
# Processing Record 23 of Set 7 | keningau
# Processing Record 24 of Set 7 | shimoda
# Processing Record 25 of Set 7 | kalmunai
# Processing Record 26 of Set 7 | zadonsk
# Processing Record 27 of Set 7 | thompson
# Processing Record 28 of Set 7 | nyurba
# Processing Record 29 of Set 7 | fort mcmurray
# Processing Record 30 of Set 7 | trujillo
# Processing Record 31 of Set 7 | brechin
# Processing Record 32 of Set 7 | gisborne
# Processing Record 33 of Set 7 | yeppoon
# Processing Record 34 of Set 7 | nyala
# Processing Record 35 of Set 7 | dundaga
# Processing Record 36 of Set 7 | kodinsk
# Processing Record 37 of Set 7 | nioki
# Processing Record 38 of Set 7 | crucecita
# Processing Record 39 of Set 7 | uturoa
# Processing Record 40 of Set 7 | usogorsk
# Processing Record 41 of Set 7 | muli
# Processing Record 42 of Set 7 | saint-francois
# Processing Record 43 of Set 7 | kijang
# Processing Record 44 of Set 7 | gubkin
# Processing Record 45 of Set 7 | taulaga
# Processing Record 46 of Set 7 | san pedro pochutla
# Processing Record 47 of Set 7 | kirkwall
# Processing Record 48 of Set 7 | west bay
# Processing Record 49 of Set 7 | onega
# Processing Record 0 of Set 8 | pandan
# Processing Record 1 of Set 8 | okhotsk
# Processing Record 2 of Set 8 | pyapon
# Processing Record 3 of Set 8 | vernon
# Processing Record 4 of Set 8 | namibe
# Processing Record 5 of Set 8 | haiku-pauwela
# Processing Record 6 of Set 8 | al hudaydah
# Processing Record 7 of Set 8 | kulachi
# Processing Record 8 of Set 8 | luba
# Processing Record 9 of Set 8 | huicungo
# Processing Record 10 of Set 8 | reggane
# Processing Record 11 of Set 8 | saint-philippe
# Processing Record 12 of Set 8 | panacan
# Processing Record 13 of Set 8 | nueva gerona
# Processing Record 14 of Set 8 | alofi
# Processing Record 15 of Set 8 | moree
# Processing Record 16 of Set 8 | solnechnyy
# Processing Record 17 of Set 8 | desaguadero
# Processing Record 18 of Set 8 | nkhotakota
# Processing Record 19 of Set 8 | pangai
# Processing Record 20 of Set 8 | sylvester
# Processing Record 21 of Set 8 | igarka
# Processing Record 22 of Set 8 | port-gentil
# Processing Record 23 of Set 8 | nordholz
# Processing Record 24 of Set 8 | al bawiti
# Processing Record 25 of Set 8 | lecheng
# Processing Record 26 of Set 8 | pachino
# Processing Record 27 of Set 8 | muynoq
# Processing Record 28 of Set 8 | morehead city
# Processing Record 29 of Set 8 | tibati
# Processing Record 30 of Set 8 | sake
# Processing Record 31 of Set 8 | bonthe
# Processing Record 32 of Set 8 | klyuchi
# Processing Record 33 of Set 8 | eydhafushi
# Processing Record 34 of Set 8 | sinop
# Processing Record 35 of Set 8 | tangi
# Processing Record 36 of Set 8 | howard springs
# Processing Record 37 of Set 8 | ad dabbah
# Processing Record 38 of Set 8 | la sarre
# Processing Record 39 of Set 8 | ciudad madero
# Processing Record 40 of Set 8 | ust-nera
# Processing Record 41 of Set 8 | perambalur
# Processing Record 42 of Set 8 | yanchep
# Processing Record 43 of Set 8 | oum hadjer
# Processing Record 44 of Set 8 | khanbari
# Processing Record 45 of Set 8 | kushiro
# Processing Record 46 of Set 8 | kidal
# Processing Record 47 of Set 8 | luisant
# Processing Record 48 of Set 8 | santyoku
# Processing Record 49 of Set 8 | borkum
# Processing Record 0 of Set 9 | hinthada
# Processing Record 1 of Set 9 | cole harbour
# Processing Record 2 of Set 9 | coronel du graty
# Processing Record 3 of Set 9 | kavieng
# Processing Record 4 of Set 9 | kita
# Processing Record 5 of Set 9 | almazan
# Processing Record 6 of Set 9 | tocopilla
# Processing Record 7 of Set 9 | elmendorf air force base
# City not found: elmendorf air force base. Skipping...
# Processing Record 8 of Set 9 | muroto-misakicho
# Processing Record 9 of Set 9 | burang
# Processing Record 10 of Set 9 | aasiaat
# Processing Record 11 of Set 9 | saint-joseph
# Processing Record 12 of Set 9 | fuvahmulah
# City not found: fuvahmulah. Skipping...
# Processing Record 13 of Set 9 | port moresby
# Processing Record 14 of Set 9 | taro
# Processing Record 15 of Set 9 | mabamba
# Processing Record 16 of Set 9 | ytyk-kyuyel'
# City not found: ytyk-kyuyel'. Skipping...
# Processing Record 17 of Set 9 | linxia chengguanzhen
# Processing Record 18 of Set 9 | dassun
# Processing Record 19 of Set 9 | razole
# Processing Record 20 of Set 9 | mil'kovo
# Processing Record 21 of Set 9 | east london
# Processing Record 22 of Set 9 | embi
# Processing Record 23 of Set 9 | almodovar del campo
# Processing Record 24 of Set 9 | ormara
# Processing Record 25 of Set 9 | milan
# Processing Record 26 of Set 9 | keflavik
# Processing Record 27 of Set 9 | tidjikja
# Processing Record 28 of Set 9 | kyaikkami
# Processing Record 29 of Set 9 | dalhart
# Processing Record 30 of Set 9 | boyolangu
# Processing Record 31 of Set 9 | sabang
# Processing Record 32 of Set 9 | nagykanizsa
# Processing Record 33 of Set 9 | tocache
# Processing Record 34 of Set 9 | vilyuysk
# Processing Record 35 of Set 9 | tambura
# Processing Record 36 of Set 9 | berdigestyakh
# Processing Record 37 of Set 9 | dobresti
# Processing Record 38 of Set 9 | abepura
# Processing Record 39 of Set 9 | kuanda
# Processing Record 40 of Set 9 | belyy yar
# Processing Record 41 of Set 9 | kill devil hills
# Processing Record 42 of Set 9 | berezovyy
# Processing Record 43 of Set 9 | taoudenni
# Processing Record 44 of Set 9 | ilesa
# Processing Record 45 of Set 9 | ataq
# Processing Record 46 of Set 9 | idfu
# Processing Record 47 of Set 9 | lepsy
# Processing Record 48 of Set 9 | tozkhurmato
# Processing Record 49 of Set 9 | castillos
# Processing Record 0 of Set 10 | ciudad lazaro cardenas
# Processing Record 1 of Set 10 | acarau
# Processing Record 2 of Set 10 | wajir
# Processing Record 3 of Set 10 | kavaratti
# Processing Record 4 of Set 10 | warrnambool
# Processing Record 5 of Set 10 | manaure
# Processing Record 6 of Set 10 | puerto bolivar
# Processing Record 7 of Set 10 | romankivtsi
# Processing Record 8 of Set 10 | kamaishi
# Processing Record 9 of Set 10 | shawano
# Processing Record 10 of Set 10 | undurkhaan
# Processing Record 11 of Set 10 | kampung sungai ara
# Processing Record 12 of Set 10 | sangre grande
# Processing Record 13 of Set 10 | faranah
# Processing Record 14 of Set 10 | hovd
# Processing Record 15 of Set 10 | cruz alta
# Processing Record 16 of Set 10 | timbuktu
# Processing Record 17 of Set 10 | la ronge
# Processing Record 18 of Set 10 | kupino
# Processing Record 19 of Set 10 | fairfax station
# Processing Record 20 of Set 10 | saint-leu
# Processing Record 21 of Set 10 | fredericksburg
# Processing Record 22 of Set 10 | bucerias
# Processing Record 23 of Set 10 | rexburg
# Processing Record 24 of Set 10 | la'ie
# Processing Record 25 of Set 10 | grande prairie
# Processing Record 26 of Set 10 | puyang chengguanzhen
# Processing Record 27 of Set 10 | tucumcari
# Processing Record 28 of Set 10 | bay harbor
# Processing Record 29 of Set 10 | balancan
# Processing Record 30 of Set 10 | rehoboth
# Processing Record 31 of Set 10 | bereznik
# Processing Record 32 of Set 10 | noumea
# Processing Record 33 of Set 10 | rengasdengklok
# Processing Record 34 of Set 10 | benicarlo
# Processing Record 35 of Set 10 | ashburton
# Processing Record 36 of Set 10 | puerto baquerizo moreno
# Processing Record 37 of Set 10 | pechora
# Processing Record 38 of Set 10 | puerto aysen
# Processing Record 39 of Set 10 | bodaybo
# Processing Record 40 of Set 10 | cabedelo
# Processing Record 41 of Set 10 | yuzhno-kurilsk
# Processing Record 42 of Set 10 | sydney
# Processing Record 43 of Set 10 | saint croix
# Processing Record 44 of Set 10 | luanda
# Processing Record 45 of Set 10 | nanzhang chengguanzhen
# Processing Record 46 of Set 10 | kudahuvadhoo
# Processing Record 47 of Set 10 | kuta
# Processing Record 48 of Set 10 | bemidji
# Processing Record 49 of Set 10 | hirara
# Processing Record 0 of Set 11 | vingt cinq
# City not found: vingt cinq. Skipping...
# Processing Record 1 of Set 11 | guaraniacu
# Processing Record 2 of Set 11 | mata-utu
# Processing Record 3 of Set 11 | ayaguz
# City not found: ayaguz. Skipping...
# Processing Record 4 of Set 11 | kulhudhuffushi
# Processing Record 5 of Set 11 | aguadulce
# Processing Record 6 of Set 11 | gaitania
# Processing Record 7 of Set 11 | nadvoitsy
# Processing Record 8 of Set 11 | louis trichardt
# Processing Record 9 of Set 11 | zahirabad
# Processing Record 10 of Set 11 | kenai
# Processing Record 11 of Set 11 | santiago
# Processing Record 12 of Set 11 | kerikeri
# Processing Record 13 of Set 11 | lebu
# Processing Record 14 of Set 11 | mugia
# Processing Record 15 of Set 11 | kyshtovka
# Processing Record 16 of Set 11 | manati
# Processing Record 17 of Set 11 | joshimath
# Processing Record 18 of Set 11 | mantua
# Processing Record 19 of Set 11 | machico
# Processing Record 20 of Set 11 | fatehpur sikri
# Processing Record 21 of Set 11 | rostovka
# Processing Record 22 of Set 11 | lichinga
# Processing Record 23 of Set 11 | neryungri
# Processing Record 24 of Set 11 | amga
# Processing Record 25 of Set 11 | middelburg
# Processing Record 26 of Set 11 | siracusa
# Processing Record 27 of Set 11 | williams lake
# Processing Record 28 of Set 11 | porto novo
# Processing Record 29 of Set 11 | i-n-salah
# Processing Record 30 of Set 11 | calca
# Processing Record 31 of Set 11 | corner brook
# Processing Record 32 of Set 11 | sao jose da coroa grande
# Processing Record 33 of Set 11 | la libertad
# Processing Record 34 of Set 11 | sandnessjoen
# Processing Record 35 of Set 11 | ngaoundere
# Processing Record 36 of Set 11 | pariang
# City not found: pariang. Skipping...
# Processing Record 37 of Set 11 | kozhevnikovo
# Processing Record 38 of Set 11 | teguise
# Processing Record 39 of Set 11 | zabaykal'sk
# Processing Record 40 of Set 11 | laguna
# Processing Record 41 of Set 11 | dakhla
# Processing Record 42 of Set 11 | quthing
# Processing Record 43 of Set 11 | otjimbingwe
# Processing Record 44 of Set 11 | jeddah
# Processing Record 45 of Set 11 | maintirano
# Processing Record 46 of Set 11 | prineville
# Processing Record 47 of Set 11 | rudbar
# Processing Record 48 of Set 11 | nam som
# Processing Record 49 of Set 11 | queenstown
# Processing Record 0 of Set 12 | aleksandrovsk-sakhalinskiy
# Processing Record 1 of Set 12 | salalah
# Processing Record 2 of Set 12 | shenjiamen
# Processing Record 3 of Set 12 | trairi
# Processing Record 4 of Set 12 | ghadamis
# Processing Record 5 of Set 12 | bayside
# Processing Record 6 of Set 12 | tofol
# Processing Record 7 of Set 12 | sydney mines
# Processing Record 8 of Set 12 | moranbah
# Processing Record 9 of Set 12 | fuerte olimpo
# Processing Record 10 of Set 12 | tarime
# Processing Record 11 of Set 12 | shanwei
# Processing Record 12 of Set 12 | arpajon-sur-cere
# Processing Record 13 of Set 12 | mejit
# Processing Record 14 of Set 12 | nouadhibou
# Processing Record 15 of Set 12 | morococha
# Processing Record 16 of Set 12 | mantsala
# Processing Record 17 of Set 12 | mukalla
# Processing Record 18 of Set 12 | levuka
# Processing Record 19 of Set 12 | steinbach
# Processing Record 20 of Set 12 | shitanjing
# Processing Record 21 of Set 12 | nguigmi
# Processing Record 22 of Set 12 | bom jesus
# Processing Record 23 of Set 12 | inirida
# Processing Record 24 of Set 12 | soio
# Processing Record 25 of Set 12 | lata
# Processing Record 26 of Set 12 | sao joao da barra
# Processing Record 27 of Set 12 | cam ranh
# Processing Record 28 of Set 12 | temiskaming shores
# Processing Record 29 of Set 12 | uyuni
# Processing Record 30 of Set 12 | colgong
# Processing Record 31 of Set 12 | detroit lakes
# Processing Record 32 of Set 12 | kamien pomorski
# Processing Record 33 of Set 12 | dongola
# Processing Record 34 of Set 12 | porto franco
# Processing Record 35 of Set 12 | nuku'alofa
# Processing Record 36 of Set 12 | pointe aux piments
# Processing Record 37 of Set 12 | tevragh zeina
# City not found: tevragh zeina. Skipping...
# Processing Record 38 of Set 12 | al minya
# Processing Record 39 of Set 12 | rio grande
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
import pandas as pd
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
print(city_data_df.count())
# Out:
# City          570
# Lat           570
# Lng           570
# Max Temp      570
# Humidity      570
# Cloudiness    570
# Wind Speed    570
# Country       570
# Date          570
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#         City      Lat      Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0  venadillo   4.7193 -74.9292     26.55        52          71        1.93
# 1   hamilton  39.1834 -84.5333     10.99        73           0        1.54
# 2    kalemie  -5.9475  29.1947     21.50        83         100        4.08
# 3    iqaluit  63.7506 -68.5145     -1.28        80         100        5.81
# 4   hermanus -34.4187  19.2345     12.67        59           1       10.88
#
#   Country        Date
# 0      CO  1728961683
# 1      US  1728961341
# 2      CD  1728961685
# 3      CA  1728961686
# 4      ZA  1728961688

# %%
# Export the City_Data into a csv
import os

#'output_data' directory 
if not os.path.exists("output_data"):
    os.makedirs("output_data")

city_data_df.to_csv("output_data/cities_weather_data.csv", index=False)

# %%
# Read saved data
import pandas as pd 

city_data_df = pd.read_csv("/Users/latifahjones/Desktop/Python-api-challenge/WeatherPy/output_data/cities_weather_data.csv")

# Display sample data
city_data_df.head()
# Out:
#         City      Lat      Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0  venadillo   4.7193 -74.9292     26.55        52          71        1.93
# 1   hamilton  39.1834 -84.5333     10.99        73           0        1.54
# 2    kalemie  -5.9475  29.1947     21.50        83         100        4.08
# 3    iqaluit  63.7506 -68.5145     -1.28        80         100        5.81
# 4   hermanus -34.4187  19.2345     12.67        59           1       10.88
#
#   Country        Date
# 0      CO  1728961683
# 1      US  1728961341
# 2      CD  1728961685
# 3      CA  1728961686
# 4      ZA  1728961688

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
import matplotlib.pyplot as plt

# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df["Lat"], city_data_df["Max Temp"], edgecolor='black', linewidth=1, marker='o')

# Incorporate the other graph properties
plt.title("City Latitude vs. Temperature (C)")
plt.xlabel("Latitude")
plt.ylabel("Temperature (C)")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df["Lat"], city_data_df["Humidity"], edgecolor='black', linewidths=1, marker='o')

# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity (%)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df["Lat"], city_data_df["Cloudiness"], edgecolor='black', linewidths=1, marker='o')

# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness (%)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df["Lat"], city_data_df["Wind Speed"], edgecolor='black', linewidths=1, marker='o')

# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed (m/s)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

# Function to compute and plot linear regression for each relationship
def compute_and_plot_linear_regression(df, x_vars, y_vars):
    for x_var in x_vars:
        for y_var in y_vars:
            # Get x and y data from the DataFrame
            x = df[x_var].values
            y = df[y_var].values
            
            # Check if x and y have the same length
            if len(x) != len(y):
                print(f"Error: {x_var} and {y_var} must have the same length!")
                continue
            
            # Calculate the linear regression
            slope, intercept, r_value, p_value, std_err = stats.linregress(x, y)
            regression_line = slope * x + intercept
            
            # Plot the data and regression line
            plt.scatter(x, y, color='blue', label='Data points')
            plt.plot(x, regression_line, color='red', label=f'Regression line: {x_var} vs {y_var}')
            
            # Add title and labels
            plt.title(f'Regression: {x_var} vs {y_var}')
            plt.xlabel(x_var)
            plt.ylabel(y_var)
            
            # Display R-squared value
            plt.text(0.05, 0.95, f'$R^2 = {r_value**2:.2f}$', transform=plt.gca().transAxes, fontsize=12)
            
            # Show legend and plot
            plt.legend()
            plt.show()

# Step 1: Load your dataset (make sure the file path is correct)
# For example, loading a CSV file into the DataFrame
df = pd.read_csv('your_dataset.csv')

# Step 2: Define the columns you want to use for the regression
# Replace 'A', 'B', 'C', and 'D' with your actual column names
x_vars = ['A', 'B']  # Independent variables (replace with actual column names)
y_vars = ['C', 'D']  # Dependent variables (replace with actual column names)

# Step 3: Call the function to compute and plot regressions for each pair
compute_and_plot_linear_regression(df, x_vars, y_vars)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 46
#      43 y_vars = ['C', 'D']  # List of dependent variables
#      45 # Call the function to compute and plot regressions for each pair
# ---> 46 compute_and_plot_linear_regression(df, x_vars, y_vars)
#
# NameError: name 'df' is not defined

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[city_data_df["Lat"] >= 0]

# Display sample data
northern_hemi_df.head()
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     venadillo   4.7193  -74.9292     26.55        52          71
# 1      hamilton  39.1834  -84.5333     10.99        73           0
# 3       iqaluit  63.7506  -68.5145     -1.28        80         100
# 10         mili   6.0815  171.7350     28.99        76          50
# 12  vilyuchinsk  52.9306  158.4028     13.15        62           2
#
#     Wind Speed Country        Date
# 0         1.93      CO  1728961683
# 1         1.54      US  1728961341
# 3         5.81      CA  1728961686
# 10        6.45      MH  1728961694
# 12        2.56      RU  1728961697

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[city_data_df["Lat"] < 0]

# Display sample data
southern_hemi_df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 2
#       1 # Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
# ----> 2 southern_hemi_df = city_data_df.loc[city_data_df["Lat"] < 0]
#       4 # Display sample data
#       5 southern_hemi_df.head()
#
# NameError: name 'city_data_df' is not defined

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
plot_linear_regression(northern_hemi_df["Lat"], northern_hemi_df["Max Temp"], 
                       "Temperature vs. Latitude", "Latitude", "Max Temperature (C)", "Northern Hemisphere")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 # Linear regression on Northern Hemisphere
# ----> 2 plot_linear_regression(northern_hemi_df["Lat"], northern_hemi_df["Max Temp"],
#       3                        "Temperature vs. Latitude", "Latitude", "Max Temperature (C)", "Northern Hemisphere")
#
# NameError: name 'plot_linear_regression' is not defined

# %%
# Linear regression on Southern Hemisphere
plot_linear_regression(southern_hemi_df["Lat"], southern_hemi_df["Max Temp"], 
                       "Temperature vs. Latitude", "Latitude", "Max Temperature (C)", "Southern Hemisphere")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 2
#       1 # Linear regression on Southern Hemisphere
# ----> 2 plot_linear_regression(southern_hemi_df["Lat"], southern_hemi_df["Max Temp"],
#       3                        "Temperature vs. Latitude", "Latitude", "Max Temperature (C)", "Southern Hemisphere")
#
# NameError: name 'plot_linear_regression' is not defined

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
plot_linear_regression(northern_hemi_df["Lat"], northern_hemi_df["Humidity"], 
                       "Humidity vs. Latitude", "Latitude", "Humidity (%)", "Northern Hemisphere")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 2
#       1 # Northern Hemisphere
# ----> 2 plot_linear_regression(northern_hemi_df["Lat"], northern_hemi_df["Humidity"],
#       3                        "Humidity vs. Latitude", "Latitude", "Humidity (%)", "Northern Hemisphere")
#
# NameError: name 'plot_linear_regression' is not defined

# %%
# Southern Hemisphere
plot_linear_regression(southern_hemi_df["Lat"], southern_hemi_df["Humidity"], 
                       "Humidity vs. Latitude", "Latitude", "Humidity (%)", "Southern Hemisphere")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 2
#       1 # Southern Hemisphere
# ----> 2 plot_linear_regression(southern_hemi_df["Lat"], southern_hemi_df["Humidity"],
#       3                        "Humidity vs. Latitude", "Latitude", "Humidity (%)", "Southern Hemisphere")
#
# NameError: name 'plot_linear_regression' is not defined

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
plot_linear_regression(northern_hemi_df["Lat"], northern_hemi_df["Cloudiness"], 
                       "Cloudiness vs. Latitude", "Latitude", "Cloudiness (%)", "Northern Hemisphere")

# %%
# Southern Hemisphere
plot_linear_regression(southern_hemi_df["Lat"], southern_hemi_df["Cloudiness"], 
                       "Cloudiness vs. Latitude", "Latitude", "Cloudiness (%)", "Southern Hemisphere")

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
plot_linear_regression(northern_hemi_df["Lat"], northern_hemi_df["Wind Speed"], 
                       "Wind Speed vs. Latitude", "Latitude", "Wind Speed (m/s)", "Northern Hemisphere")

# %%
# Southern Hemisphere
plot_linear_regression(southern_hemi_df["Lat"], southern_hemi_df["Wind Speed"], 
                       "Wind Speed vs. Latitude", "Latitude", "Wind Speed (m/s)", "Southern Hemisphere")

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %%
pip in

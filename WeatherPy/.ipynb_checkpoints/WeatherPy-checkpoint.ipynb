# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name

    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 587

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
import requests
import time
import random
from citipy import citipy

# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather"
weather_api_key = "be30130d8cd8c0d1146e214d31e7ff18"

# Create empty lists for latitude, longitude, and city information
latitude = []
longitude = []
cities = []

# Generate 1500 random geographic coordinates (latitude and longitude)
for _ in range(1500):
    lat = random.uniform(-90.0, 90.0)
    lon = random.uniform(-180.0, 180.0)
    latitude.append(lat)
    longitude.append(lon)

    # Use citipy to find the nearest city for each latitude/longitude combination
    city = citipy.nearest_city(lat, lon).city_name

    # Add city if it's not already in the list (to avoid duplicates)
    if city not in cities:
        cities.append(city)

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in your list to fetch weather data
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{url}?q={city}&appid={weather_api_key}&units=metric"

    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({
            "City": city,
            "Lat": city_lat,
            "Lng": city_lng,
            "Max Temp": city_max_temp,
            "Humidity": city_humidity,
            "Cloudiness": city_clouds,
            "Wind Speed": city_wind,
            "Country": city_country,
            "Date": city_date
        })

    # If an error is experienced, skip the city
    except Exception as e:
        print(f"City not found: {city}. Skipping...")

    # Pause to avoid rate limiting
    time.sleep(1)

# Indicate that Data Loading is complete
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | ushuaia
# Processing Record 2 of Set 1 | bethel
# Processing Record 3 of Set 1 | port mathurin
# Processing Record 4 of Set 1 | tofol
# Processing Record 5 of Set 1 | isafjordur
# Processing Record 6 of Set 1 | waitangi
# Processing Record 7 of Set 1 | byron bay
# Processing Record 8 of Set 1 | kingston
# Processing Record 9 of Set 1 | ilulissat
# Processing Record 10 of Set 1 | bredasdorp
# Processing Record 11 of Set 1 | port-aux-francais
# Processing Record 12 of Set 1 | hamilton
# Processing Record 13 of Set 1 | kalat
# Processing Record 14 of Set 1 | ulladulla
# Processing Record 15 of Set 1 | qaqortoq
# Processing Record 16 of Set 1 | bayanhongor
# Processing Record 17 of Set 1 | hawaiian paradise park
# Processing Record 18 of Set 1 | llanes
# Processing Record 19 of Set 1 | anadyr
# Processing Record 20 of Set 1 | roja
# Processing Record 21 of Set 1 | talnakh
# Processing Record 22 of Set 1 | saynshand
# Processing Record 23 of Set 1 | ahau
# City not found: ahau. Skipping...
# Processing Record 24 of Set 1 | mulanur
# Processing Record 25 of Set 1 | mount gambier
# Processing Record 26 of Set 1 | ust-nera
# Processing Record 27 of Set 1 | olonkinbyen
# Processing Record 28 of Set 1 | manicore
# Processing Record 29 of Set 1 | jamestown
# Processing Record 30 of Set 1 | avarua
# Processing Record 31 of Set 1 | inhambane
# Processing Record 32 of Set 1 | port augusta
# Processing Record 33 of Set 1 | elverum
# Processing Record 34 of Set 1 | grytviken
# Processing Record 35 of Set 1 | puerto natales
# Processing Record 36 of Set 1 | st. john's
# Processing Record 37 of Set 1 | remire-montjoly
# Processing Record 38 of Set 1 | namtsy
# Processing Record 39 of Set 1 | horta
# Processing Record 40 of Set 1 | jean-rabel
# Processing Record 41 of Set 1 | praia da vitoria
# Processing Record 42 of Set 1 | atafu village
# Processing Record 43 of Set 1 | nabire
# Processing Record 44 of Set 1 | houthalen
# Processing Record 45 of Set 1 | sogndal
# Processing Record 46 of Set 1 | stanley
# Processing Record 47 of Set 1 | uturoa
# Processing Record 48 of Set 1 | kill devil hills
# Processing Record 49 of Set 1 | hasaki
# Processing Record 50 of Set 1 | sinop
# Processing Record 0 of Set 2 | edinburgh of the seven seas
# Processing Record 1 of Set 2 | bredy
# Processing Record 2 of Set 2 | taiohae
# City not found: taiohae. Skipping...
# Processing Record 3 of Set 2 | amga
# Processing Record 4 of Set 2 | port elizabeth
# Processing Record 5 of Set 2 | hermanus
# Processing Record 6 of Set 2 | thompson
# Processing Record 7 of Set 2 | keflavik
# Processing Record 8 of Set 2 | gisborne
# Processing Record 9 of Set 2 | dudinka
# Processing Record 10 of Set 2 | espargos
# City not found: espargos. Skipping...
# Processing Record 11 of Set 2 | alotau
# Processing Record 12 of Set 2 | babu
# Processing Record 13 of Set 2 | rio grande
# Processing Record 14 of Set 2 | bilibino
# Processing Record 15 of Set 2 | mount isa
# Processing Record 16 of Set 2 | west island
# Processing Record 17 of Set 2 | fort mcmurray
# Processing Record 18 of Set 2 | sorokino
# Processing Record 19 of Set 2 | albany
# Processing Record 20 of Set 2 | vorgashor
# Processing Record 21 of Set 2 | livingston
# Processing Record 22 of Set 2 | arraial do cabo
# Processing Record 23 of Set 2 | el porvenir
# Processing Record 24 of Set 2 | iqaluit
# Processing Record 25 of Set 2 | palangkaraya
# Processing Record 26 of Set 2 | sarangani
# Processing Record 27 of Set 2 | happy valley-goose bay
# Processing Record 28 of Set 2 | sheksna
# Processing Record 29 of Set 2 | margaret river
# Processing Record 30 of Set 2 | college
# Processing Record 31 of Set 2 | kodiak
# Processing Record 32 of Set 2 | dalbandin
# Processing Record 33 of Set 2 | launceston
# Processing Record 34 of Set 2 | pa daet
# Processing Record 35 of Set 2 | tolanaro
# Processing Record 36 of Set 2 | shangri-la
# City not found: shangri-la. Skipping...
# Processing Record 37 of Set 2 | san antonio de pale
# Processing Record 38 of Set 2 | tra mhor
# Processing Record 39 of Set 2 | broome
# Processing Record 40 of Set 2 | fortuna
# Processing Record 41 of Set 2 | usinsk
# Processing Record 42 of Set 2 | adamstown
# Processing Record 43 of Set 2 | magadan
# Processing Record 44 of Set 2 | longyearbyen
# Processing Record 45 of Set 2 | udachny
# Processing Record 46 of Set 2 | fale old settlement
# Processing Record 47 of Set 2 | lihue
# Processing Record 48 of Set 2 | vingt cinq
# City not found: vingt cinq. Skipping...
# Processing Record 49 of Set 2 | borba
# Processing Record 0 of Set 3 | blackmans bay
# Processing Record 1 of Set 3 | heidesheim
# Processing Record 2 of Set 3 | puerto ayora
# Processing Record 3 of Set 3 | mthatha
# Processing Record 4 of Set 3 | berezovyy
# Processing Record 5 of Set 3 | ribeira grande
# Processing Record 6 of Set 3 | bikenibeu village
# Processing Record 7 of Set 3 | enewetak
# Processing Record 8 of Set 3 | weihai
# Processing Record 9 of Set 3 | rosedale
# Processing Record 10 of Set 3 | imeni morozova
# Processing Record 11 of Set 3 | yellowknife
# Processing Record 12 of Set 3 | childress
# Processing Record 13 of Set 3 | tiksi
# Processing Record 14 of Set 3 | codrington
# Processing Record 15 of Set 3 | khambhat
# Processing Record 16 of Set 3 | colonia
# Processing Record 17 of Set 3 | katsuura
# Processing Record 18 of Set 3 | lebu
# Processing Record 19 of Set 3 | chinde
# Processing Record 20 of Set 3 | myitkyina
# Processing Record 21 of Set 3 | jeremie
# Processing Record 22 of Set 3 | boundiali
# Processing Record 23 of Set 3 | muzambinho
# Processing Record 24 of Set 3 | mount pearl
# Processing Record 25 of Set 3 | sambava
# Processing Record 26 of Set 3 | tarko-sale
# Processing Record 27 of Set 3 | hami
# Processing Record 28 of Set 3 | coyhaique
# Processing Record 29 of Set 3 | invercargill
# Processing Record 30 of Set 3 | cumaribo
# City not found: cumaribo. Skipping...
# Processing Record 31 of Set 3 | miramar
# Processing Record 32 of Set 3 | daru
# Processing Record 33 of Set 3 | qamdo
# Processing Record 34 of Set 3 | zhumysker
# Processing Record 35 of Set 3 | alsfeld
# Processing Record 36 of Set 3 | la punta
# Processing Record 37 of Set 3 | utrik
# Processing Record 38 of Set 3 | sitka
# Processing Record 39 of Set 3 | aswan
# Processing Record 40 of Set 3 | antsohimbondrona
# City not found: antsohimbondrona. Skipping...
# Processing Record 41 of Set 3 | margate
# Processing Record 42 of Set 3 | polyarnyy
# Processing Record 43 of Set 3 | mugia
# Processing Record 44 of Set 3 | tura
# Processing Record 45 of Set 3 | tromso
# Processing Record 46 of Set 3 | petauke
# Processing Record 47 of Set 3 | peterhead
# Processing Record 48 of Set 3 | baikonur
# Processing Record 49 of Set 3 | imbituba
# Processing Record 0 of Set 4 | arno
# Processing Record 1 of Set 4 | sao joao da barra
# Processing Record 2 of Set 4 | holualoa
# Processing Record 3 of Set 4 | fuvahmulah
# City not found: fuvahmulah. Skipping...
# Processing Record 4 of Set 4 | loei
# Processing Record 5 of Set 4 | crane
# Processing Record 6 of Set 4 | pisco
# Processing Record 7 of Set 4 | dzilam gonzalez
# Processing Record 8 of Set 4 | oranjemund
# Processing Record 9 of Set 4 | arua
# Processing Record 10 of Set 4 | kedrovyy
# Processing Record 11 of Set 4 | rikaze
# Processing Record 12 of Set 4 | berastagi
# Processing Record 13 of Set 4 | island harbour
# Processing Record 14 of Set 4 | bethal
# Processing Record 15 of Set 4 | tevriz
# Processing Record 16 of Set 4 | villa gesell
# Processing Record 17 of Set 4 | machico
# Processing Record 18 of Set 4 | kruisfontein
# Processing Record 19 of Set 4 | horqueta
# Processing Record 20 of Set 4 | nar'yan-mar
# Processing Record 21 of Set 4 | susuman
# Processing Record 22 of Set 4 | porto seguro
# Processing Record 23 of Set 4 | goundam
# Processing Record 24 of Set 4 | azhikkal
# Processing Record 25 of Set 4 | petropavlovsk-kamchatsky
# Processing Record 26 of Set 4 | amuntai
# Processing Record 27 of Set 4 | port lincoln
# Processing Record 28 of Set 4 | soe
# Processing Record 29 of Set 4 | yakeshi
# Processing Record 30 of Set 4 | vila franca do campo
# Processing Record 31 of Set 4 | paragominas
# Processing Record 32 of Set 4 | papatowai
# Processing Record 33 of Set 4 | morden
# Processing Record 34 of Set 4 | paola
# Processing Record 35 of Set 4 | altamira
# Processing Record 36 of Set 4 | nova sintra
# Processing Record 37 of Set 4 | punta arenas
# Processing Record 38 of Set 4 | lianshan
# Processing Record 39 of Set 4 | helena valley west central
# Processing Record 40 of Set 4 | kristiansund
# Processing Record 41 of Set 4 | dibba al-hisn
# Processing Record 42 of Set 4 | camana
# Processing Record 43 of Set 4 | wailua homesteads
# Processing Record 44 of Set 4 | tranovaho
# City not found: tranovaho. Skipping...
# Processing Record 45 of Set 4 | langepas
# Processing Record 46 of Set 4 | aasiaat
# Processing Record 47 of Set 4 | yuzhno-kurilsk
# Processing Record 48 of Set 4 | barra de santo antonio
# Processing Record 49 of Set 4 | aykhal
# Processing Record 0 of Set 5 | dalandzadgad
# Processing Record 1 of Set 5 | satwas
# Processing Record 2 of Set 5 | verdal
# Processing Record 3 of Set 5 | dakhla
# Processing Record 4 of Set 5 | mabaruma
# Processing Record 5 of Set 5 | raj-nandgaon
# Processing Record 6 of Set 5 | bubaque
# Processing Record 7 of Set 5 | matadi
# Processing Record 8 of Set 5 | laredo
# Processing Record 9 of Set 5 | boyolangu
# Processing Record 10 of Set 5 | torghay
# Processing Record 11 of Set 5 | yaren
# Processing Record 12 of Set 5 | alofi
# Processing Record 13 of Set 5 | ruteng
# Processing Record 14 of Set 5 | jincheng
# Processing Record 15 of Set 5 | lobujya
# Processing Record 16 of Set 5 | barra dos coqueiros
# Processing Record 17 of Set 5 | weno
# Processing Record 18 of Set 5 | santiago de cao
# Processing Record 19 of Set 5 | linxia chengguanzhen
# Processing Record 20 of Set 5 | north bend
# Processing Record 21 of Set 5 | tumayr
# Processing Record 22 of Set 5 | alesund
# Processing Record 23 of Set 5 | coxen hole
# Processing Record 24 of Set 5 | jimma
# Processing Record 25 of Set 5 | sao vicente
# Processing Record 26 of Set 5 | 'ohonua
# City not found: 'ohonua. Skipping...
# Processing Record 27 of Set 5 | severnoye
# Processing Record 28 of Set 5 | saint croix
# Processing Record 29 of Set 5 | jalai nur
# Processing Record 30 of Set 5 | borazjan
# Processing Record 31 of Set 5 | ponta delgada
# Processing Record 32 of Set 5 | doaba
# Processing Record 33 of Set 5 | puerto baquerizo moreno
# Processing Record 34 of Set 5 | huilong
# Processing Record 35 of Set 5 | ytyk-kyuyel'
# City not found: ytyk-kyuyel'. Skipping...
# Processing Record 36 of Set 5 | chulakkurgan
# Processing Record 37 of Set 5 | kanor
# Processing Record 38 of Set 5 | poletayevo
# Processing Record 39 of Set 5 | pangai
# Processing Record 40 of Set 5 | coahuayana de hidalgo
# Processing Record 41 of Set 5 | kotel'nich
# Processing Record 42 of Set 5 | istaravshan
# Processing Record 43 of Set 5 | saipan
# Processing Record 44 of Set 5 | saldanha
# Processing Record 45 of Set 5 | breves
# Processing Record 46 of Set 5 | rawson
# Processing Record 47 of Set 5 | cargados carajos
# City not found: cargados carajos. Skipping...
# Processing Record 48 of Set 5 | mejit
# Processing Record 49 of Set 5 | frontera
# Processing Record 0 of Set 6 | buka
# Processing Record 1 of Set 6 | mhamid
# Processing Record 2 of Set 6 | kiunga
# Processing Record 3 of Set 6 | itoman
# Processing Record 4 of Set 6 | yuli
# Processing Record 5 of Set 6 | tantoyuca
# Processing Record 6 of Set 6 | coruripe
# Processing Record 7 of Set 6 | kone
# Processing Record 8 of Set 6 | mora
# Processing Record 9 of Set 6 | luderitz
# Processing Record 10 of Set 6 | kolokani
# Processing Record 11 of Set 6 | la'ie
# Processing Record 12 of Set 6 | vila velha
# Processing Record 13 of Set 6 | acarau
# Processing Record 14 of Set 6 | le port
# Processing Record 15 of Set 6 | moorhead
# Processing Record 16 of Set 6 | shaowu
# Processing Record 17 of Set 6 | whitehorse
# Processing Record 18 of Set 6 | namibe
# Processing Record 19 of Set 6 | camalu
# Processing Record 20 of Set 6 | veraval
# Processing Record 21 of Set 6 | forster
# Processing Record 22 of Set 6 | taoudenni
# Processing Record 23 of Set 6 | queenstown
# Processing Record 24 of Set 6 | nambucca heads
# Processing Record 25 of Set 6 | san antonio oeste
# Processing Record 26 of Set 6 | north platte
# Processing Record 27 of Set 6 | badger
# Processing Record 28 of Set 6 | kavadarci
# Processing Record 29 of Set 6 | grigoropolisskaya
# Processing Record 30 of Set 6 | trzic
# Processing Record 31 of Set 6 | port alfred
# Processing Record 32 of Set 6 | pizarro
# Processing Record 33 of Set 6 | ciudad lazaro cardenas
# Processing Record 34 of Set 6 | pante makasar
# City not found: pante makasar. Skipping...
# Processing Record 35 of Set 6 | barentu
# Processing Record 36 of Set 6 | monte cristo
# Processing Record 37 of Set 6 | ambon
# Processing Record 38 of Set 6 | alo
# Processing Record 39 of Set 6 | salalah
# Processing Record 40 of Set 6 | vizinga
# Processing Record 41 of Set 6 | poiana mare
# Processing Record 42 of Set 6 | sokoni
# Processing Record 43 of Set 6 | ndele
# Processing Record 44 of Set 6 | tortoli
# Processing Record 45 of Set 6 | canoinhas
# Processing Record 46 of Set 6 | fujin
# Processing Record 47 of Set 6 | callao
# Processing Record 48 of Set 6 | san patricio
# Processing Record 49 of Set 6 | caleta de carquin
# Processing Record 0 of Set 7 | sinabang
# Processing Record 1 of Set 7 | tazovsky
# Processing Record 2 of Set 7 | santa isabel
# Processing Record 3 of Set 7 | kostomuksha
# Processing Record 4 of Set 7 | brookings
# Processing Record 5 of Set 7 | georgetown
# Processing Record 6 of Set 7 | batticaloa
# Processing Record 7 of Set 7 | dhar
# Processing Record 8 of Set 7 | barcelos
# Processing Record 9 of Set 7 | ostersund
# Processing Record 10 of Set 7 | carnarvon
# Processing Record 11 of Set 7 | pembroke
# Processing Record 12 of Set 7 | zhob
# Processing Record 13 of Set 7 | vorkuta
# Processing Record 14 of Set 7 | latakia
# Processing Record 15 of Set 7 | afaahiti
# Processing Record 16 of Set 7 | bardai
# Processing Record 17 of Set 7 | clarence town
# Processing Record 18 of Set 7 | ziro
# Processing Record 19 of Set 7 | okha
# Processing Record 20 of Set 7 | greenville
# Processing Record 21 of Set 7 | al hazm
# Processing Record 22 of Set 7 | ar rutbah
# Processing Record 23 of Set 7 | ust-tsilma
# Processing Record 24 of Set 7 | hauterive
# Processing Record 25 of Set 7 | la passe
# Processing Record 26 of Set 7 | pyinmana
# Processing Record 27 of Set 7 | antalaha
# Processing Record 28 of Set 7 | chengde
# Processing Record 29 of Set 7 | klyuchi
# Processing Record 30 of Set 7 | princeville
# Processing Record 31 of Set 7 | ocean shores
# Processing Record 32 of Set 7 | geraldton
# Processing Record 33 of Set 7 | diawara
# Processing Record 34 of Set 7 | key largo
# Processing Record 35 of Set 7 | okhotsk
# Processing Record 36 of Set 7 | lerwick
# Processing Record 37 of Set 7 | nadi
# Processing Record 38 of Set 7 | saint-francois
# Processing Record 39 of Set 7 | zeya
# Processing Record 40 of Set 7 | port hedland
# Processing Record 41 of Set 7 | lillehammer
# Processing Record 42 of Set 7 | takoradi
# Processing Record 43 of Set 7 | touros
# Processing Record 44 of Set 7 | hammerfest
# Processing Record 45 of Set 7 | aketi
# Processing Record 46 of Set 7 | durango
# Processing Record 47 of Set 7 | stephenville
# Processing Record 48 of Set 7 | lodeynoye pole
# Processing Record 49 of Set 7 | cornwall
# Processing Record 0 of Set 8 | east london
# Processing Record 1 of Set 8 | sabinas
# Processing Record 2 of Set 8 | perelyub
# Processing Record 3 of Set 8 | harper
# Processing Record 4 of Set 8 | dadukou
# Processing Record 5 of Set 8 | ibipeba
# Processing Record 6 of Set 8 | sassandra
# Processing Record 7 of Set 8 | ola
# Processing Record 8 of Set 8 | makurazaki
# Processing Record 9 of Set 8 | kataragama
# City not found: kataragama. Skipping...
# Processing Record 10 of Set 8 | lagos
# Processing Record 11 of Set 8 | sehwan
# Processing Record 12 of Set 8 | puerto san jose
# Processing Record 13 of Set 8 | joshimath
# Processing Record 14 of Set 8 | chonchi
# Processing Record 15 of Set 8 | levuka
# Processing Record 16 of Set 8 | salinopolis
# Processing Record 17 of Set 8 | richards bay
# Processing Record 18 of Set 8 | kavaratti
# Processing Record 19 of Set 8 | sao martinho
# Processing Record 20 of Set 8 | mineros
# Processing Record 21 of Set 8 | thomaston
# Processing Record 22 of Set 8 | hithadhoo
# Processing Record 23 of Set 8 | akureyri
# Processing Record 24 of Set 8 | alaghsas
# Processing Record 25 of Set 8 | terme
# Processing Record 26 of Set 8 | suratgarh
# Processing Record 27 of Set 8 | iquique
# Processing Record 28 of Set 8 | port saint john's
# Processing Record 29 of Set 8 | challapata
# Processing Record 30 of Set 8 | xai-xai
# Processing Record 31 of Set 8 | mana
# Processing Record 32 of Set 8 | zapata
# Processing Record 33 of Set 8 | mahabe
# City not found: mahabe. Skipping...
# Processing Record 34 of Set 8 | kourou
# Processing Record 35 of Set 8 | essaouira
# Processing Record 36 of Set 8 | ceerigaabo
# Processing Record 37 of Set 8 | uttarkashi
# Processing Record 38 of Set 8 | colares
# Processing Record 39 of Set 8 | meadow lake
# Processing Record 40 of Set 8 | nemuro
# Processing Record 41 of Set 8 | guigang
# Processing Record 42 of Set 8 | ivdel'
# Processing Record 43 of Set 8 | sonsorol village
# City not found: sonsorol village. Skipping...
# Processing Record 44 of Set 8 | iwon-up
# Processing Record 45 of Set 8 | chibougamau
# Processing Record 46 of Set 8 | cadillac
# Processing Record 47 of Set 8 | saint-pierre
# Processing Record 48 of Set 8 | astrea
# Processing Record 49 of Set 8 | itaituba
# Processing Record 0 of Set 9 | fomboni
# Processing Record 1 of Set 9 | vilyuchinsk
# Processing Record 2 of Set 9 | labrador city
# Processing Record 3 of Set 9 | maturin
# Processing Record 4 of Set 9 | cerro de pasco
# Processing Record 5 of Set 9 | kailua-kona
# Processing Record 6 of Set 9 | karlovac
# Processing Record 7 of Set 9 | paungde
# Processing Record 8 of Set 9 | penon blanco
# Processing Record 9 of Set 9 | myrtle beach
# Processing Record 10 of Set 9 | tonghua
# Processing Record 11 of Set 9 | balboa
# Processing Record 12 of Set 9 | manacapuru
# Processing Record 13 of Set 9 | hinton
# Processing Record 14 of Set 9 | jacarezinho
# Processing Record 15 of Set 9 | laminusa
# Processing Record 16 of Set 9 | fort bragg
# Processing Record 17 of Set 9 | kapuskasing
# Processing Record 18 of Set 9 | krakow
# Processing Record 19 of Set 9 | nafada
# Processing Record 20 of Set 9 | tataouine
# Processing Record 21 of Set 9 | capayan
# Processing Record 22 of Set 9 | vinings
# Processing Record 23 of Set 9 | minas de marcona
# Processing Record 24 of Set 9 | haiku-pauwela
# Processing Record 25 of Set 9 | cururupu
# Processing Record 26 of Set 9 | dhidhdhoo
# Processing Record 27 of Set 9 | markovo
# Processing Record 28 of Set 9 | carinhanha
# Processing Record 29 of Set 9 | dompu
# Processing Record 30 of Set 9 | ust'-ilimsk
# Processing Record 31 of Set 9 | lata
# Processing Record 32 of Set 9 | georgievka
# Processing Record 33 of Set 9 | konarka
# Processing Record 34 of Set 9 | mossel bay
# Processing Record 35 of Set 9 | zalegoshch'
# Processing Record 36 of Set 9 | tarinkot
# Processing Record 37 of Set 9 | ras gharib
# City not found: ras gharib. Skipping...
# Processing Record 38 of Set 9 | howrah
# Processing Record 39 of Set 9 | boa viagem
# Processing Record 40 of Set 9 | rancho palos verdes
# Processing Record 41 of Set 9 | popondetta
# Processing Record 42 of Set 9 | quang ngai
# Processing Record 43 of Set 9 | dongfeng
# Processing Record 44 of Set 9 | chauk
# Processing Record 45 of Set 9 | kizel
# Processing Record 46 of Set 9 | sarnia
# Processing Record 47 of Set 9 | arar
# Processing Record 48 of Set 9 | inarajan village
# Processing Record 49 of Set 9 | salinas
# Processing Record 0 of Set 10 | cedeira
# Processing Record 1 of Set 10 | constantia
# Processing Record 2 of Set 10 | ananindeua
# Processing Record 3 of Set 10 | tewantin
# Processing Record 4 of Set 10 | novokazalinsk
# City not found: novokazalinsk. Skipping...
# Processing Record 5 of Set 10 | el calafate
# Processing Record 6 of Set 10 | lorengau
# Processing Record 7 of Set 10 | bandarbeyla
# Processing Record 8 of Set 10 | cidreira
# Processing Record 9 of Set 10 | new norfolk
# Processing Record 10 of Set 10 | hadibu
# Processing Record 11 of Set 10 | egilsstadir
# Processing Record 12 of Set 10 | orange walk
# Processing Record 13 of Set 10 | bartica
# Processing Record 14 of Set 10 | turbat
# Processing Record 15 of Set 10 | kununurra
# Processing Record 16 of Set 10 | lazaro cardenas
# Processing Record 17 of Set 10 | bonthe
# Processing Record 18 of Set 10 | maceio
# Processing Record 19 of Set 10 | yeonggwang
# Processing Record 20 of Set 10 | richmond hill
# Processing Record 21 of Set 10 | hirara
# Processing Record 22 of Set 10 | mirnyy
# Processing Record 23 of Set 10 | merida
# Processing Record 24 of Set 10 | rudnyy
# Processing Record 25 of Set 10 | kuala terengganu
# Processing Record 26 of Set 10 | umm al quwain city
# Processing Record 27 of Set 10 | jose mariano jimenez
# City not found: jose mariano jimenez. Skipping...
# Processing Record 28 of Set 10 | aldinga beach
# Processing Record 29 of Set 10 | sainte-marie
# Processing Record 30 of Set 10 | santana
# Processing Record 31 of Set 10 | governor's harbour
# City not found: governor's harbour. Skipping...
# Processing Record 32 of Set 10 | nadezhda
# Processing Record 33 of Set 10 | hwado
# Processing Record 34 of Set 10 | dubbo
# Processing Record 35 of Set 10 | par naogaon
# Processing Record 36 of Set 10 | brisas de zicatela
# Processing Record 37 of Set 10 | santa eulalia
# Processing Record 38 of Set 10 | alakurtti
# Processing Record 39 of Set 10 | chernyshevskiy
# Processing Record 40 of Set 10 | yerofey pavlovich
# Processing Record 41 of Set 10 | kenai
# Processing Record 42 of Set 10 | tandag
# Processing Record 43 of Set 10 | ovruch
# Processing Record 44 of Set 10 | ashkelon
# Processing Record 45 of Set 10 | malabar
# Processing Record 46 of Set 10 | khorixas
# Processing Record 47 of Set 10 | angaur state
# Processing Record 48 of Set 10 | isangel
# Processing Record 49 of Set 10 | matoury
# Processing Record 0 of Set 11 | lincoln city
# Processing Record 1 of Set 11 | val-des-monts
# Processing Record 2 of Set 11 | ancud
# Processing Record 3 of Set 11 | qui nhon
# Processing Record 4 of Set 11 | arauco
# Processing Record 5 of Set 11 | tamanrasset
# Processing Record 6 of Set 11 | darwin
# Processing Record 7 of Set 11 | mar del plata
# Processing Record 8 of Set 11 | kavieng
# Processing Record 9 of Set 11 | asipovichy
# Processing Record 10 of Set 11 | springbok
# Processing Record 11 of Set 11 | beira
# Processing Record 12 of Set 11 | bueng kan
# Processing Record 13 of Set 11 | awjilah
# Processing Record 14 of Set 11 | prado
# Processing Record 15 of Set 11 | west fargo
# Processing Record 16 of Set 11 | tommot
# Processing Record 17 of Set 11 | valdivia
# Processing Record 18 of Set 11 | apodi
# Processing Record 19 of Set 11 | mount pleasant
# Processing Record 20 of Set 11 | kostanay
# Processing Record 21 of Set 11 | sierra grande
# Processing Record 22 of Set 11 | tual
# Processing Record 23 of Set 11 | nova olimpia
# Processing Record 24 of Set 11 | birao
# Processing Record 25 of Set 11 | gaspe
# Processing Record 26 of Set 11 | divnogorsk
# Processing Record 27 of Set 11 | huangshan
# Processing Record 28 of Set 11 | lianran
# Processing Record 29 of Set 11 | galliano
# Processing Record 30 of Set 11 | punta del este
# Processing Record 31 of Set 11 | iskateley
# Processing Record 32 of Set 11 | toliara
# Processing Record 33 of Set 11 | yacuiba
# Processing Record 34 of Set 11 | chardara
# Processing Record 35 of Set 11 | dryden
# Processing Record 36 of Set 11 | robbah
# Processing Record 37 of Set 11 | lingyuan
# Processing Record 38 of Set 11 | bam
# Processing Record 39 of Set 11 | la sarre
# Processing Record 40 of Set 11 | praia
# Processing Record 41 of Set 11 | cerro azul
# Processing Record 42 of Set 11 | scheveningen
# Processing Record 43 of Set 11 | nuuk
# Processing Record 44 of Set 11 | makokou
# Processing Record 45 of Set 11 | thulamahashi
# Processing Record 46 of Set 11 | wenling
# Processing Record 47 of Set 11 | lompoc
# Processing Record 48 of Set 11 | karystos
# Processing Record 49 of Set 11 | ugoofaaru
# Processing Record 0 of Set 12 | kuwait city
# Processing Record 1 of Set 12 | nova vicosa
# Processing Record 2 of Set 12 | kaisiadorys
# Processing Record 3 of Set 12 | conneaut
# Processing Record 4 of Set 12 | khosta
# Processing Record 5 of Set 12 | bratca
# Processing Record 6 of Set 12 | villaguay
# Processing Record 7 of Set 12 | huaicheng
# Processing Record 8 of Set 12 | swakopmund
# Processing Record 9 of Set 12 | yinzhu
# Processing Record 10 of Set 12 | vadso
# Processing Record 11 of Set 12 | la ronge
# Processing Record 12 of Set 12 | kidal
# Processing Record 13 of Set 12 | labuan
# Processing Record 14 of Set 12 | devinuwara
# City not found: devinuwara. Skipping...
# Processing Record 15 of Set 12 | fort st. john
# Processing Record 16 of Set 12 | lincoln
# Processing Record 17 of Set 12 | antsiranana
# Processing Record 18 of Set 12 | glace bay
# Processing Record 19 of Set 12 | argo
# Processing Record 20 of Set 12 | cobija
# Processing Record 21 of Set 12 | mwinilunga
# Processing Record 22 of Set 12 | kimbe
# Processing Record 23 of Set 12 | tombodu
# Processing Record 24 of Set 12 | sorong
# Processing Record 25 of Set 12 | penzance
# Processing Record 26 of Set 12 | shevchenko
# Processing Record 27 of Set 12 | porto novo
# Processing Record 28 of Set 12 | troitsko-pechorsk
# Processing Record 29 of Set 12 | decize
# Processing Record 30 of Set 12 | sandnessjoen
# Processing Record 31 of Set 12 | rurrenabaque
# Processing Record 32 of Set 12 | novoishimskiy
# Processing Record 33 of Set 12 | itabaiana
# Processing Record 34 of Set 12 | bathurst
# Processing Record 35 of Set 12 | hillsboro
# Processing Record 36 of Set 12 | el granada
# Processing Record 37 of Set 12 | drayton valley
# Processing Record 38 of Set 12 | jiwani
# Processing Record 39 of Set 12 | tokar
# Processing Record 40 of Set 12 | balotra
# Processing Record 41 of Set 12 | sarkand
# Processing Record 42 of Set 12 | dunedin
# Processing Record 43 of Set 12 | palikir - national government center
# Processing Record 44 of Set 12 | ust'-uda
# Processing Record 45 of Set 12 | qibray
# Processing Record 46 of Set 12 | bakaly
# Processing Record 47 of Set 12 | luwuk
# Processing Record 48 of Set 12 | ubari
# Processing Record 49 of Set 12 | obo
# Processing Record 0 of Set 13 | ocosingo
# Processing Record 1 of Set 13 | lionel town
# Processing Record 2 of Set 13 | dolinsk
# Processing Record 3 of Set 13 | saudarkrokur
# Processing Record 4 of Set 13 | kurkino
# Processing Record 5 of Set 13 | luganville
# Processing Record 6 of Set 13 | kilindoni
# Processing Record 7 of Set 13 | altai
# Processing Record 8 of Set 13 | zouerate
# Processing Record 9 of Set 13 | heihe
# Processing Record 10 of Set 13 | jerome
# Processing Record 11 of Set 13 | tralee
# Processing Record 12 of Set 13 | enshi
# Processing Record 13 of Set 13 | nikolayevsk-on-amure
# Processing Record 14 of Set 13 | vasarosnameny
# Processing Record 15 of Set 13 | guerrero negro
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
import pandas as pd
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
print(city_data_df.count())
# Out:
# City          595
# Lat           595
# Lng           595
# Max Temp      595
# Humidity      595
# Cloudiness    595
# Wind Speed    595
# Country       595
# Date          595
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        ushuaia -54.8000  -68.3000     10.81        46           0
# 1         bethel  41.3712  -73.4140      8.36        69         100
# 2  port mathurin -19.6833   63.4167     22.09        68         100
# 3          tofol   5.3248  163.0078     30.88        70          75
# 4     isafjordur  66.0755  -23.1240     -1.02        79          58
#
#    Wind Speed Country        Date
# 0        6.17      AR  1728955623
# 1        1.34      US  1728956134
# 2        8.36      MU  1728956135
# 3        3.60      FM  1728956136
# 4        2.64      IS  1728956137

# %%
# Export the City_Data into a csv
import os

#'output_data' directory 
if not os.path.exists("output_data"):
    os.makedirs("output_data")

city_data_df.to_csv("output_data/cities_weather_data.csv", index=False)

# %%
# Read saved data
import pandas as pd 

city_data_df.to_csv("/Users/latifahjones/Desktop/Python-api-challenge/WeatherPy/output_data/cities.csv", index_label="City_ID")

# Display sample data
city_data_df.head()
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        ushuaia -54.8000  -68.3000     10.81        46           0
# 1         bethel  41.3712  -73.4140      8.36        69         100
# 2  port mathurin -19.6833   63.4167     22.09        68         100
# 3          tofol   5.3248  163.0078     30.88        70          75
# 4     isafjordur  66.0755  -23.1240     -1.02        79          58
#
#    Wind Speed Country        Date
# 0        6.17      AR  1728955623
# 1        1.34      US  1728956134
# 2        8.36      MU  1728956135
# 3        3.60      FM  1728956136
# 4        2.64      IS  1728956137

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
import matplotlib.pyplot as plt

# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df["Lat"], city_data_df["Max Temp"], edgecolor='black', linewidth=1, marker='o')

# Incorporate the other graph properties
plt.title("City Latitude vs. Temperature (C)")
plt.xlabel("Latitude")
plt.ylabel("Temperature (C)")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df["Lat"], city_data_df["Humidity"], edgecolor='black', linewidths=1, marker='o')

# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity (%)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df["Lat"], city_data_df["Cloudiness"], edgecolor='black', linewidths=1, marker='o')

# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness (%)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df["Lat"], city_data_df["Wind Speed"], edgecolor='black', linewidths=1, marker='o')

# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed (m/s)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Drop rows with missing values for the Northern Hemisphere
northern_hemi_df = northern_hemi_df.dropna(subset=["Lat", "Max Temp"])

# Drop rows with missing values for the Southern Hemisphere
southern_hemi_df = southern_hemi_df.dropna(subset=["Lat", "Max Temp"])

# Ensure data is numeric in Northern Hemisphere
northern_hemi_df["Lat"] = pd.to_numeric(northern_hemi_df["Lat"], errors='coerce')
northern_hemi_df["Max Temp"] = pd.to_numeric(northern_hemi_df["Max Temp"], errors='coerce')

# Ensure data is numeric in Southern Hemisphere
southern_hemi_df["Lat"] = pd.to_numeric(southern_hemi_df["Lat"], errors='coerce')
southern_hemi_df["Max Temp"] = pd.to_numeric(southern_hemi_df["Max Temp"], errors='coerce')

import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

# Define a function to create Linear Regression plots
def create_linear_regression_plot(x, y, title, xlabel, ylabel):
    # Calculate the linear regression
    slope, intercept, r_value, p_value, std_err = stats.linregress(x, y)

    # Create the regression line
    regression_line = slope * x + intercept

    # Create the scatter plot
    plt.scatter(x, y, color='blue', label='Data points')
    plt.plot(x, regression_line, color='red', label='Regression line')

    # Add title and labels
    plt.title(title)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)

    # Display the r-squared value on the plot
    plt.text(0.05, 0.95, f'$R^2 = {r_value**2:.2f}$', transform=plt.gca().transAxes)

    # Show legend
    plt.legend()

    # Display the plot
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 2
#       1 # Drop rows with missing values for the Northern Hemisphere
# ----> 2 northern_hemi_df = northern_hemi_df.dropna(subset=["Lat", "Max Temp"])
#       4 # Drop rows with missing values for the Southern Hemisphere
#       5 southern_hemi_df = southern_hemi_df.dropna(subset=["Lat", "Max Temp"])
#
# NameError: name 'northern_hemi_df' is not defined

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[city_data_df["Lat"] >= 0]

# Display sample data
northern_hemi_df.head()
# Out:
#          City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 1      bethel  41.3712  -73.4140      8.36        69         100        1.34
# 3       tofol   5.3248  163.0078     30.88        70          75        3.60
# 4  isafjordur  66.0755  -23.1240     -1.02        79          58        2.64
# 7    kingston  17.9970  -76.7936     29.53        74          20        4.12
# 8   ilulissat  69.2167  -51.1000     -0.99        80         100        7.20
#
#   Country        Date
# 1      US  1728956134
# 3      FM  1728956136
# 4      IS  1728956137
# 7      JM  1728955843
# 8      GL  1728956142

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[city_data_df["Lat"] < 0]

# Display sample data
southern_hemi_df.head()
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        ushuaia -54.8000  -68.3000     10.81        46           0
# 2  port mathurin -19.6833   63.4167     22.09        68         100
# 5       waitangi -43.9535 -176.5597     11.33        85          19
# 6      byron bay -28.6500  153.6167     20.92        81          82
# 9     bredasdorp -34.5322   20.0403     13.31        54          46
#
#    Wind Speed Country        Date
# 0        6.17      AR  1728955623
# 2        8.36      MU  1728956135
# 5        6.47      NZ  1728956138
# 6        1.48      AU  1728956140
# 9        8.00      ZA  1728956056

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
plot_linear_regression(northern_hemi_df["Lat"], northern_hemi_df["Max Temp"], 
                       "Temperature vs. Latitude", "Latitude", "Max Temperature (C)", "Northern Hemisphere")
# Out:
# The r-squared is: 0.7304123168866145

# %%
# Linear regression on Southern Hemisphere
plot_linear_regression(southern_hemi_df["Lat"], southern_hemi_df["Max Temp"], 
                       "Temperature vs. Latitude", "Latitude", "Max Temperature (C)", "Southern Hemisphere")
# Out:
# The r-squared is: 0.569495773648159

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
plot_linear_regression(northern_hemi_df["Lat"], northern_hemi_df["Humidity"], 
                       "Humidity vs. Latitude", "Latitude", "Humidity (%)", "Northern Hemisphere")
# Out:
# The r-squared is: 0.005000651238438018

# %%
# Southern Hemisphere
plot_linear_regression(southern_hemi_df["Lat"], southern_hemi_df["Humidity"], 
                       "Humidity vs. Latitude", "Latitude", "Humidity (%)", "Southern Hemisphere")
# Out:
# The r-squared is: 0.000475485697295476

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
plot_linear_regression(northern_hemi_df["Lat"], northern_hemi_df["Cloudiness"], 
                       "Cloudiness vs. Latitude", "Latitude", "Cloudiness (%)", "Northern Hemisphere")
# Out:
# The r-squared is: 0.014533090239573141

# %%
# Southern Hemisphere
plot_linear_regression(southern_hemi_df["Lat"], southern_hemi_df["Cloudiness"], 
                       "Cloudiness vs. Latitude", "Latitude", "Cloudiness (%)", "Southern Hemisphere")
# Out:
# The r-squared is: 0.01217260033638656

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
plot_linear_regression(northern_hemi_df["Lat"], northern_hemi_df["Wind Speed"], 
                       "Wind Speed vs. Latitude", "Latitude", "Wind Speed (m/s)", "Northern Hemisphere")
# Out:
# The r-squared is: 0.04307710599994257

# %%
# Southern Hemisphere
plot_linear_regression(southern_hemi_df["Lat"], southern_hemi_df["Wind Speed"], 
                       "Wind Speed vs. Latitude", "Latitude", "Wind Speed (m/s)", "Southern Hemisphere")
# Out:
# The r-squared is: 0.08174079104660249

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %%
pip in
